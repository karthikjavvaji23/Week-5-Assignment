# %% [markdown]
# # Data Science Automation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# Load the data
df = pd.read_csv(r'C:\Users\rames\Downloads\Karthik\updated_churn_data.csv')
columns_to_drop = ['Tenure_Category', 'MonthlyCharges_log', 'TotalCharges_log']
df = df.drop(columns=columns_to_drop)
df.head()
# Out:
#    tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0       1             0         0              2           29.85
# 1      34             1         1              3           56.95
# 2       2             1         0              3           53.85
# 3      45             0         1              0           42.30
# 4       2             1         0              2           70.70
#
#    TotalCharges  Churn
# 0         29.85      0
# 1       1889.50      0
# 2        108.15      1
# 3       1840.75      0
# 4        151.65      1

# %% [markdown]
# We are using pycaret to find an ML algorithm that performs best on the data

# %%
pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (3.3.2)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: cloudpickle in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: numba>=0.55.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.60.0)
# Requirement already satisfied: jinja2>=3 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.1.4)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\rames\appdata\roaming\python\python39\site-packages (from pycaret) (8.18.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\rames\appdata\roaming\python\python39\site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: pandas<2.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: sktime==0.26.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: schemdraw==0.15 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.14.3)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (4.66.5)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (8.1.5)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.1.5)
# Requirement already satisfied: requests>=2.27.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.32.3)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (2.6.4)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: xxhash in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\rames\appdata\roaming\python\python39\site-packages (from pycaret) (6.0.0)
# Requirement already satisfied: packaging in c:\users\rames\appdata\roaming\python\python39\site-packages (from sktime==0.26.0->pycaret) (24.1)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\rames\appdata\roaming\python\python39\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.20.2)
# Requirement already satisfied: typing-extensions in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (4.12.2)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (2.18.0)
# Requirement already satisfied: matplotlib-inline in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: decorator in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: jedi>=0.16 in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (0.19.1)
# Requirement already satisfied: colorama in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: stack-data in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (3.0.48)
# Requirement already satisfied: exceptiongroup in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipython>=5.5.0->pycaret) (1.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.13)
# Requirement already satisfied: comm>=0.1.3 in c:\users\rames\appdata\roaming\python\python39\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\rames\appdata\roaming\python\python39\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.1.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rames\appdata\roaming\python\python39\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (6.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (10.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.54.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\rames\appdata\roaming\python\python39\site-packages (from nbformat>=4.2.0->pycaret) (5.7.2)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2023.12.1)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (24.2.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.20.0)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.35.1)
# Requirement already satisfied: pywin32>=300 in c:\users\rames\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (306)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\rames\appdata\roaming\python\python39\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.3.6)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from numba>=0.55.0->pycaret) (0.43.0)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pandas<2.2.0->pycaret) (2024.2)
# Requirement already satisfied: six in c:\users\rames\appdata\roaming\python\python39\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from plotly>=5.14.0->pycaret) (9.0.0)
# Requirement already satisfied: dash>=2.9.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.3)
# Requirement already satisfied: setuptools in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (56.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.4)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: nest-asyncio in c:\users\rames\appdata\roaming\python\python39\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: retrying in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: click>=8.1.3 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.8.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: urllib3 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.2.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: wcwidth in c:\users\rames\appdata\roaming\python\python39\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.13)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->pycaret) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->pycaret) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rames\appdata\local\programs\python\python39\lib\site-packages (from requests>=2.27.1->pycaret) (2024.8.30)
# Requirement already satisfied: executing>=1.2.0 in c:\users\rames\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\rames\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\rames\appdata\roaming\python\python39\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.3; however, version 24.2 is available.
# You should consider upgrading via the 'c:\Users\rames\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# We are choosing Precision metric as it optimizes the model to minimize false positives, which is crucial when false alarms.

# %%
from pycaret.classification import *
clf_setup = setup(data=df, target='Churn', session_id=123, 
                  preprocess=True, normalize=True, 
                  remove_multicollinearity=True, multicollinearity_threshold=0.95, 
                  ignore_features=['customerID'])
# Compare all models based on precision
best_model = compare_models(sort='Precision')
print(best_model)
evaluate_model(best_model)
tuned_model = tune_model(best_model, optimize='Precision')
evaluate_model(tuned_model)
# Out:
# <style type="text/css">
# #T_0d68b_row9_col1, #T_0d68b_row13_col1, #T_0d68b_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0d68b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d68b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0d68b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d68b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0d68b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0d68b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0d68b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0d68b_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0d68b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0d68b_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0d68b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_0d68b_row3_col1" class="data row3 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0d68b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_0d68b_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0d68b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_0d68b_row5_col1" class="data row5 col1" >(4930, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0d68b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_0d68b_row6_col1" class="data row6 col1" >(2113, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0d68b_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_0d68b_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0d68b_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_0d68b_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0d68b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0d68b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0d68b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0d68b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0d68b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0d68b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0d68b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0d68b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0d68b_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_0d68b_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0d68b_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_0d68b_row14_col1" class="data row14 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0d68b_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_0d68b_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0d68b_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_0d68b_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0d68b_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_0d68b_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0d68b_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_0d68b_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0d68b_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_0d68b_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0d68b_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_0d68b_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0d68b_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_0d68b_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_0d68b_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_0d68b_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0d68b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_0d68b_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_0d68b_row23_col1" class="data row23 col1" >29e5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_daf21 th {
#   text-align: left;
# }
# #T_daf21_row0_col0, #T_daf21_row0_col1, #T_daf21_row0_col2, #T_daf21_row0_col3, #T_daf21_row0_col5, #T_daf21_row0_col6, #T_daf21_row0_col7, #T_daf21_row1_col0, #T_daf21_row1_col3, #T_daf21_row1_col4, #T_daf21_row1_col5, #T_daf21_row1_col6, #T_daf21_row1_col7, #T_daf21_row2_col0, #T_daf21_row2_col1, #T_daf21_row2_col2, #T_daf21_row2_col3, #T_daf21_row2_col4, #T_daf21_row2_col5, #T_daf21_row2_col6, #T_daf21_row2_col7, #T_daf21_row3_col0, #T_daf21_row3_col1, #T_daf21_row3_col2, #T_daf21_row3_col3, #T_daf21_row3_col4, #T_daf21_row3_col5, #T_daf21_row3_col6, #T_daf21_row3_col7, #T_daf21_row4_col0, #T_daf21_row4_col1, #T_daf21_row4_col2, #T_daf21_row4_col3, #T_daf21_row4_col4, #T_daf21_row4_col5, #T_daf21_row4_col7, #T_daf21_row5_col0, #T_daf21_row5_col1, #T_daf21_row5_col2, #T_daf21_row5_col3, #T_daf21_row5_col4, #T_daf21_row5_col5, #T_daf21_row5_col6, #T_daf21_row5_col7, #T_daf21_row6_col0, #T_daf21_row6_col1, #T_daf21_row6_col2, #T_daf21_row6_col3, #T_daf21_row6_col4, #T_daf21_row6_col5, #T_daf21_row6_col6, #T_daf21_row6_col7, #T_daf21_row7_col0, #T_daf21_row7_col1, #T_daf21_row7_col2, #T_daf21_row7_col3, #T_daf21_row7_col4, #T_daf21_row7_col5, #T_daf21_row7_col6, #T_daf21_row7_col7, #T_daf21_row8_col0, #T_daf21_row8_col1, #T_daf21_row8_col2, #T_daf21_row8_col3, #T_daf21_row8_col4, #T_daf21_row8_col5, #T_daf21_row8_col6, #T_daf21_row8_col7, #T_daf21_row9_col0, #T_daf21_row9_col1, #T_daf21_row9_col2, #T_daf21_row9_col3, #T_daf21_row9_col4, #T_daf21_row9_col5, #T_daf21_row9_col6, #T_daf21_row9_col7, #T_daf21_row10_col0, #T_daf21_row10_col1, #T_daf21_row10_col2, #T_daf21_row10_col3, #T_daf21_row10_col4, #T_daf21_row10_col6, #T_daf21_row11_col0, #T_daf21_row11_col1, #T_daf21_row11_col2, #T_daf21_row11_col3, #T_daf21_row11_col4, #T_daf21_row11_col5, #T_daf21_row11_col6, #T_daf21_row11_col7, #T_daf21_row12_col0, #T_daf21_row12_col1, #T_daf21_row12_col2, #T_daf21_row12_col4, #T_daf21_row12_col5, #T_daf21_row12_col6, #T_daf21_row12_col7, #T_daf21_row13_col0, #T_daf21_row13_col1, #T_daf21_row13_col2, #T_daf21_row13_col3, #T_daf21_row13_col4, #T_daf21_row13_col5, #T_daf21_row13_col6, #T_daf21_row13_col7 {
#   text-align: left;
# }
# #T_daf21_row0_col4, #T_daf21_row1_col1, #T_daf21_row1_col2, #T_daf21_row4_col6, #T_daf21_row10_col5, #T_daf21_row10_col7, #T_daf21_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_daf21_row0_col8, #T_daf21_row5_col8, #T_daf21_row10_col8, #T_daf21_row11_col8, #T_daf21_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# #T_daf21_row1_col8, #T_daf21_row2_col8, #T_daf21_row3_col8, #T_daf21_row4_col8, #T_daf21_row6_col8, #T_daf21_row7_col8, #T_daf21_row8_col8, #T_daf21_row9_col8, #T_daf21_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# </style>
# <table id="T
td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2c765_row5_col0" class="data row5 col0" >0.7748</td>
#       <td id="T_2c765_row5_col1" class="data row5 col1" >0.8095</td>
#       <td id="T_2c765_row5_col2" class="data row5 col2" >0.4733</td>
#       <td id="T_2c765_row5_col3" class="data row5 col3" >0.5962</td>
#       <td id="T_2c765_row5_col4" class="data row5 col4" >0.5277</td>
#       <td id="T_2c765_row5_col5" class="data row5 col5" >0.3824</td>
#       <td id="T_2c765_row5_col6" class="data row5 col6" >0.3868</td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2c765_row6_col0" class="data row6 col0" >0.7951</td>
#       <td id="T_2c765_row6_col1" class="data row6 col1" >0.8382</td>
#       <td id="T_2c765_row6_col2" class="data row6 col2" >0.4122</td>
#       <td id="T_2c765_row6_col3" class="data row6 col3" >0.6923</td>
#       <td id="T_2c765_row6_col4" class="data row6 col4" >0.5167</td>
#       <td id="T_2c765_row6_col5" class="data row6 col5" >0.3972</td>
#       <td id="T_2c765_row6_col6" class="data row6 col6" >0.4187</td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2c765_row7_col0" class="data row7 col0" >0.7931</td>
#       <td id="T_2c765_row7_col1" class="data row7 col1" >0.8222</td>
#       <td id="T_2c765_row7_col2" class="data row7 col2" >0.4046</td>
#       <td id="T_2c765_row7_col3" class="data row7 col3" >0.6883</td>
#       <td id="T_2c765_row7_col4" class="data row7 col4" >0.5096</td>
#       <td id="T_2c765_row7_col5" class="data row7 col5" >0.3895</td>
#       <td id="T_2c765_row7_col6" class="data row7 col6" >0.4116</td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2c765_row8_col0" class="data row8 col0" >0.8174</td>
#       <td id="T_2c765_row8_col1" class="data row8 col1" >0.8282</td>
#       <td id="T_2c765_row8_col2" class="data row8 col2" >0.4962</td>
#       <td id="T_2c765_row8_col3" class="data row8 col3" >0.7303</td>
#       <td id="T_2c765_row8_col4" class="data row8 col4" >0.5909</td>
#       <td id="T_2c765_row8_col5" class="data row8 col5" >0.4789</td>
#       <td id="T_2c765_row8_col6" class="data row8 col6" >0.4937</td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2c765_row9_col0" class="data row9 col0" >0.7870</td>
#       <td id="T_2c765_row9_col1" class="data row9 col1" >0.8253</td>
#       <td id="T_2c765_row9_col2" class="data row9 col2" >0.3817</td>
#       <td id="T_2c765_row9_col3" class="data row9 col3" >0.6757</td>
#       <td id="T_2c765_row9_col4" class="data row9 col4" >0.4878</td>
#       <td id="T_2c765_row9_col5" class="data row9 col5" >0.3662</td>
#       <td id="T_2c765_row9_col6" class="data row9 col6" >0.3900</td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2c765_row10_col0" class="data row10 col0" >0.7915</td>
#       <td id="T_2c765_row10_col1" class="data row10 col1" >0.8186</td>
#       <td id="T_2c765_row10_col2" class="data row10 col2" >0.4511</td>
#       <td id="T_2c765_row10_col3" class="data row10 col3" >0.6584</td>
#       <td id="T_2c765_row10_col4" class="data row10 col4" >0.5338</td>
#       <td id="T_2c765_row10_col5" class="data row10 col5" >0.4058</td>
#       <td id="T_2c765_row10_col6" class="data row10 col6" >0.4186</td>
#     </tr>
#     <tr>
#       <th id="T_2c765_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2c765_row11_col0" class="data row11 col0" >0.0143</td>
#       <td id="T_2c765_row11_col1" class="data row11 col1" >0.0126</td>
#       <td id="T_2c765_row11_col2" class="data row11 col2" >0.0405</td>
#       <td id="T_2c765_row11_col3" class="data row11 col3" >0.0443</td>
#       <td id="T_2c765_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# We are saving the best Precision model onto to disk

# %%
from pycaret.classification import save_model

save_model(tuned_model, 'best_churn_model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'PhoneService',
#                                               'Contract', 'PaymentMethod',
#                                               'MonthlyCharges', 'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,
#                                                                missing_values=nan,
#                                                                strategy='mean'))),
#                  ('categorical_imputer',...
#                                      transformer=RemoveMulticollinearity(threshold=0.95))),
#                  ('normalize',
#                   TransformerWrapper(exclude=None, include=None,
#                                      transformer=StandardScaler(copy=True,
#                                                                 with_mean=True,
#                                                                 with_std=True))),
#                  ('trained_model',
#                   RidgeClassifier(alpha=7.68, class_weight=None, copy_X=True,
#                                   fit_intercept=True, max_iter=None,
#                                   positive=False, random_state=123,
#                                   solver='auto', tol=0.0001))],
#           verbose=False),
#  'best_churn_model.pkl')

# %% [markdown]
# Now, we are creating a Python script with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe.

# %%
from pycaret.classification import load_model, predict_model

df = pd.read_csv(r'C:\Users\rames\Downloads\Karthik\updated_churn_data.csv')
df.replace([np.inf, -np.inf], np.nan, inplace=True)

clf_setup = setup(data=df, target='Churn', session_id=123)

# Compare models and select the one that supports predict_proba
best_model = compare_models(sort='Precision')

# Check if the best model supports predict_proba
if hasattr(best_model, 'predict_proba'):
    print(f"The best model is: {best_model.__class__.__name__}")
else:
    print("The best model does not support predict_proba.")
    
# Predict probabilities using the chosen model
def predict_churn_probability(df):
    # Load the pre-trained model
    model = load_model('best_churn_model')  # Adjust this based on your saved model

    # Check if the required columns exist
    required_columns = ['tenure', 'PhoneService', 'Contract', 'PaymentMethod', 'MonthlyCharges',
       'TotalCharges', 'Tenure_Category', 'MonthlyCharges_log',
       'TotalCharges_log']
    for col in required_columns:
        if col not in df.columns:
            raise KeyError(f"Column '{col}' not found in DataFrame.")

    # Predict probabilities of churn
    probabilities = model.predict_proba(df[required_columns])[:, 1]  # Assuming positive class is at index 1
    
    # Add the probabilities to the DataFrame
    df['Churn_Probability'] = probabilities
    
    return df
# Out:
# <style type="text/css">
# #T_43cf7_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_43cf7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43cf7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_43cf7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43cf7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43cf7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_43cf7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43cf7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_43cf7_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43cf7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_43cf7_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43cf7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_43cf7_row3_col1" class="data row3 col1" >(7043, 10)</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43cf7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_43cf7_row4_col1" class="data row4 col1" >(7043, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_43cf7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_43cf7_row5_col1" class="data row5 col1" >(4930, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_43cf7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_43cf7_row6_col1" class="data row6 col1" >(2113, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_43cf7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_43cf7_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_43cf7_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_43cf7_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_43cf7_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_43cf7_row9_col1" class="data row9 col1" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_43cf7_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_43cf7_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_43cf7_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_43cf7_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_43cf7_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_43cf7_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_43cf7_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_43cf7_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_43cf7_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_43cf7_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_43cf7_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_43cf7_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_43cf7_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_43cf7_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_43cf7_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_43cf7_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_43cf7_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_43cf7_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_43cf7_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_43cf7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_43cf7_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_43cf7_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_43cf7_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_43cf7_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_43cf7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_43cf7_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_43cf7_row22_col1" class="data row22 col1" >34c1</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_88a51 th {
#   text-align: left;
# }
# #T_88a51_row0_col0, #T_88a51_row0_col2, #T_88a51_row0_col3, #T_88a51_row0_col5, #T_88a51_row0_col6, #T_88a51_row0_col7, #T_88a51_row1_col0, #T_88a51_row1_col1, #T_88a51_row1_col2, #T_88a51_row1_col3, #T_88a51_row1_col4, #T_88a51_row1_col5, #T_88a51_row2_col0, #T_88a51_row2_col1, #T_88a51_row2_col2, #T_88a51_row2_col3, #T_88a51_row2_col4, #T_88a51_row2_col5, #T_88a51_row2_col6, #T_88a51_row
tenure', 'PhoneService', 'Contract', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn', 'Tenure_Category', 'MonthlyCharges_log',
#        'TotalCharges_log'],
#       dtype='object')

# %% [markdown]
# Creating the function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe

# %% [markdown]
#   Using the Python function should print out the predictions for new data, while also looking at the true values for the new data.

# %%
from pycaret.classification import load_model, predict_model

def predict_churn_probabilities(df):

    # Load the trained churn model
    model = load_model('best_churn_model')  # Ensure this model is saved previously

    # Predict on the DataFrame and return predictions including probabilities
    predictions = predict_model(model, data=df)

    # Return the DataFrame with original features and probabilities
    print("\nPredictions DataFrame:\n", predictions)
    if 'Score' in predictions.columns and 'Label' in predictions.columns:
        return predictions[['Score', 'Label']]
    elif 'prediction_score' in predictions.columns and 'prediction_label' in predictions.columns:
        return predictions[['prediction_score', 'prediction_label']]
    else:
        raise ValueError("Expected columns are not found in the predictions DataFrame.")

if __name__ == "__main__":
    # Load new churn data
    new_data_path = 'new_churn_data.csv'
    new_data = pd.read_csv(r'C:\Users\rames\Downloads\Karthik\new_churn_data.csv')

    # Display the first few rows of the new data for inspection
    print("New data loaded:\n", new_data.head())

    # Get the churn probabilities
    churn_probabilities = predict_churn_probabilities(new_data)

    # Print the probabilities and predictions
    print("\nChurn probabilities and predictions:\n", churn_probabilities)

    # True values for the new data
    true_values = [1, 0, 0, 1, 0]  # True values for the new data
    print("\nTrue Values:\n", true_values)
# Out:
# New data loaded:
#     customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0  9305-CKSKC      22             1         0              2           97.40
# 1  1452-KNGVK       8             0         1              1           77.30
# 2  6723-OKKJM      28             1         0              0           28.25
# 3  7832-POPKP      62             1         0              2          101.70
# 4  6348-TACGU      10             0         0              1           51.15
#
#    TotalCharges  charge_per_tenure
# 0        811.70          36.895455
# 1       1701.95         212.743750
# 2        250.90           8.960714
# 3       3106.56          50.105806
# 4       3440.97         344.097000
# Transformation Pipeline and Model Successfully Loaded
# Predictions DataFrame:
#     customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0  9305-CKSKC      22             1         0              2       97.400002
# 1  1452-KNGVK       8             0         1              1       77.300003
# 2  6723-OKKJM      28             1         0              0       28.250000
# 3  7832-POPKP      62             1         0              2      101.699997
# 4  6348-TACGU      10             0         0              1       51.150002
#
#    TotalCharges  charge_per_tenure  prediction_label  prediction_score
# 0    811.700012          36.895454                 0            0.5743
# 1   1701.949951         212.743744                 0            0.8786
# 2    250.899994           8.960714                 0            0.8878
# 3   3106.560059          50.105808                 0            0.6541
# 4   3440.969971         344.096985                 0            0.7141
#
# Churn probabilities and predictions:
#     prediction_score  prediction_label
# 0            0.5743                 0
# 1            0.8786                 0
# 2            0.8878                 0
# 3            0.6541                 0
# 4            0.7141                 0
#
# True Values:
#  [1, 0, 0, 1, 0]

# %% [markdown]
# To make the dataset more accurate we are cleaning it by dropping missing values

# %%
import pandas as pd
import numpy as np

def clean_data(df):
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    print("NaN values before dropping:", df.isna().sum())
    df.dropna(inplace=True)

    print("NaN values after dropping:", df.isna().sum())
    for col in df.select_dtypes(include=[np.number]).columns:
        if df[col].max() > 1e6:  # Adjust threshold based on your domain knowledge
            print(f"Capping values in column {col} at 1e6.")
            df[col] = np.clip(df[col], None, 1e6)  # Cap values to a maximum of 1e6
    return df

if __name__ == "__main__":
    # Load the initial churn data for training
    train_data_path = 'your_initial_data.csv'  # Replace with your actual data path
    train_data = pd.read_csv

# %% [markdown]
# Testing the Python module and function on the new data file

# %%
import numpy as np
from pycaret.classification import load_model, predict_model, setup, create_model, save_model

def clean_data(df):
    """
    Cleans the DataFrame by handling infinite values, NaNs, and outliers.

    Parameters:
    df (pd.DataFrame): The DataFrame to clean.

    Returns:
    pd.DataFrame: The cleaned DataFrame.
    """
    # Replace infinite values with NaN
    df.replace([np.inf, -np.inf], np.nan, inplace=True)
    
    # Check for and count NaN values
    print("NaN values before dropping:", df.isna().sum())
    
    # Drop rows with NaN values
    df.dropna(inplace=True)

    # Check for and count remaining NaN values
    print("NaN values after dropping:", df.isna().sum())

    # Detect and cap extreme values (example threshold)
    for col in df.select_dtypes(include=[np.number]).columns:
        if df[col].max() > 1e6:  # Adjust threshold based on your domain knowledge
            print(f"Capping values in column {col} at 1e6.")
            df[col] = np.clip(df[col], None, 1e6)  # Cap values to a maximum of 1e6

    return df

def train_gradient_boosting_model(df):
    """
    Trains a Gradient Boosting model on the given DataFrame and saves the model.
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing customer data for training.
    """
    # Setup PyCaret with the data
    clf = setup(data=df, target='Churn', session_id=123)

    # Create and train the Gradient Boosting model
    gb_model = create_model('gbc')  # 'gbc' stands for Gradient Boosting Classifier

    # Save the trained model
    save_model(gb_model, 'gradient_boosting_model')

def predict_churn_probabilities(df):
    """
    Predicts the churn probabilities for each row in the given DataFrame.
    
    Parameters:
    df (pd.DataFrame): The DataFrame containing customer data for prediction.
    
    Returns:
    pd.DataFrame: A DataFrame with the original data and the predicted churn probabilities.
    """
    # Load the trained churn model
    model = load_model('gradient_boosting_model')

    # Predict on the DataFrame and return predictions
    predictions = predict_model(model, data=df)

    # Print the predictions DataFrame to check its structure
    print("\nPredictions DataFrame:\n", predictions)

    # Return relevant columns
    return predictions[['Score', 'Label']]

if __name__ == "__main__":
    # Load the initial churn data for training
    train_data_path = r'C:\Users\rames\Downloads\Karthik\updated_churn_data.csv' 
    train_data = pd.read_csv(train_data_path)

    # Clean the training data
    train_data = clean_data(train_data)

    # Train the Gradient Boosting model
    train_gradient_boosting_model(train_data)

    # Load new churn data for predictions
    new_data_path = r'C:\Users\rames\Downloads\Karthik\new_churn_data.csv'
    new_data = pd.read_csv(new_data_path)

    # Clean the new data
    new_data = clean_data(new_data)

    # Display the first few rows of the new data for inspection
    print("New data loaded:\n", new_data.head())

    # Optionally, drop columns that are not needed for prediction
    columns_to_drop = ['Tenure_Category', 'MonthlyCharges_log', 'TotalCharges_log']  # Adjust as necessary
    new_data = new_data.drop(columns=[col for col in columns_to_drop if col in new_data.columns], errors='ignore')

    # Get the churn probabili
# Out:
# NaN values before dropping: tenure                 0
# PhoneService           0
# Contract               0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# Churn                  0
# Tenure_Category        0
# MonthlyCharges_log     0
# TotalCharges_log      11
# dtype: int64
# NaN values after dropping: tenure                0
# PhoneService          0
# Contract              0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# Churn                 0
# Tenure_Category       0
# MonthlyCharges_log    0
# TotalCharges_log      0
# dtype: int64
# <style type="text/css">
# #T_f6ec0_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_
td>
#     </tr>
#     <tr>
#       <th id="T_a4d95_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a4d95_row9_col0" class="data row9 col0" >0.8049</td>
#       <td id="T_a4d95_row9_col1" class="data row9 col1" >0.8619</td>
#       <td id="T_a4d95_row9_col2" class="data row9 col2" >0.5420</td>
#       <td id="T_a4d95_row9_col3" class="data row9 col3" >0.6636</td>
#       <td id="T_a4d95_row9_col4" class="data row9 col4" >0.5966</td>
#       <td id="T_a4d95_row9_col5" class="data row9 col5" >0.4697</td>
#       <td id="T_a4d95_row9_col6" class="data row9 col6" >0.4739</td>
#     </tr>
#     <tr>
#       <th id="T_a4d95_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_a4d95_row10_col0" class="data row10 col0" >0.7976</td>
#       <td id="T_a4d95_row10_col1" class="data row10 col1" >0.8404</td>
#       <td id="T_a4d95_row10_col2" class="data row10 col2" >0.5046</td>
#       <td id="T_a4d95_row10_col3" class="data row10 col3" >0.6569</td>
#       <td id="T_a4d95_row10_col4" class="data row10 col4" >0.5699</td>
#       <td id="T_a4d95_row10_col5" class="data row10 col5" >0.4406</td>
#       <td id="T_a4d95_row10_col6" class="data row10 col6" >0.4477</td>
#     </tr>
#     <tr>
#       <th id="T_a4d95_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_a4d95_row11_col0" class="data row11 col0" >0.0147</td>
#       <td id="T_a4d95_row11_col1" class="data row11 col1" >0.0227</td>
#       <td id="T_a4d95_row11_col2" class="data row11 col2" >0.0308</td>
#       <td id="T_a4d95_row11_col3" class="data row11 col3" >0.0424</td>
#       <td id="T_a4d95_row11_col4
# Transformation Pipeline and Model Successfully Saved
# NaN values before dropping: customerID           0
# tenure               0
# PhoneService         0
# Contract             0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges         0
# charge_per_tenure    0
# dtype: int64
# NaN values after dropping: customerID           0
# tenure               0
# PhoneService         0
# Contract             0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges         0
# charge_per_tenure    0
# dtype: int64
# New data loaded:
#     customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0  9305-CKSKC      22             1         0              2           97.40
# 1  1452-KNGVK       8             0         1              1           77.30
# 2  6723-OKKJM      28             1         0              0           28.25
# 3  7832-POPKP      62             1         0              2          101.70
# 4  6348-TACGU      10             0         0              1           51.15
#
#    TotalCharges  charge_per_tenure
# 0        811.70          36.895455
# 1       1701.95         212.743750
# 2        250.90           8.960714
# 3       3106.56          50.105806
# 4       3440.97         344.097000

# %%
from pycaret.classification import load_model, predict_model

# Step 2: Load your trained model
model = load_model('best_churn_model')

# Step 3: Predict on the new churn data
# Use predict_model to make predictions
predictions = predict_model(model, data=new_data)

# Step 4: Display the predictions
print(predictions)
# Out:
# Transformation Pipeline and Model Successfully Loaded
#    customerID  tenure  PhoneService  Contract  PaymentMethod  MonthlyCharges  \
# 0  9305-CKSKC      22             1         0              2       97.400002
# 1  1452-KNGVK       8             0         1              1       77.300003
# 2  6723-OKKJM      28             1         0              0       28.250000
# 3  7832-POPKP      62             1         0              2      101.699997
# 4  6348-TACGU      10             0         0              1       51.150002
#
#    TotalCharges  charge_per_tenure  prediction_label  prediction_score
# 0    811.700012          36.895454                 0            0.5743
# 1   1701.949951         212.743744                 0            0.8786
# 2    250.899994           8.960714                 0            0.8878
# 3   3106.560059          50.105808                 0            0.6541
# 4   3440.969971         344.096985                 0            0.7141

# %% [markdown]
# The Above are the predictions that the Python module was able to make based on the trained data. Giving us prediction scores ranging from 0.5743 to 0.8786

# %% [markdown]
# # Summary:
# In this assignment, we worked on using PyCaret to check churn predictions, which helped us to observe the customer churn probabilities based on the features. We are choosing Precision metric as it optimizes the model to minimize false positives, which is crucial when false alarms.
# The prediction scores ranged from 0.5743 to 0.8786 indicating the model's confidence in these predictions, with higher scores suggesting a greater likelihood of retention. By  looking at these prediction scores, the Telecom business can identify customers who are likely to churn those with lower scores and can make targeted strategies to retain them.
